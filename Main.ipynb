# %%
from DataService import DataService
from KerasModels import KerasModels
from EnvironmentSettings import EnvironmentSettings
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-dda2f5809c85> in <module>
# ----> 1 from DataService import DataService
#       2 from KerasModels import KerasModels
#       3 from EnvironmentSettings import EnvironmentSettings
#       4 import matplotlib.pyplot as plt
#
# /storage/cancer_detection/tensorflow/Histopathologic-Cancer-Detection-Tensorflow2/DataService.py in <module>
# ----> 1 import pandas as pd
#       2 import os
#       3 from glob import glob
#       4 from sklearn.model_selection import train_test_split
#       5 from imgaug import augmenters as iaa
#
# ModuleNotFoundError: No module named 'pandas'

# %%
ENV_SETTINGS = EnvironmentSettings("PAPERSPACE")
data_service = DataService(ENV_SETTINGS.train, ENV_SETTINGS.val, ENV_SETTINGS.labels, "tif")

# %%
data_service.load(True)
# Out:
# labeled_files size : 220025
# test_files size : 57458

# %%
keras_models = KerasModels(ENV_SETTINGS.checkpoint + "/NASNetMobile.h5", data_service, batch_size = ENV_SETTINGS.batch_size)

# %%
model = keras_models.build_NASNetMobile(weights = "imagenet")
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            (None, 96, 96, 3)    0
# __________________________________________________________________________________________________
# NASNet (Model)                  (None, 3, 3, 1056)   4269716     input_1[0][0]
# __________________________________________________________________________________________________
# global_max_pooling2d_1 (GlobalM (None, 1056)         0           NASNet[1][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_1 (Glo (None, 1056)         0           NASNet[1][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 9504)         0           NASNet[1][0]
# ...

# %%
keras_models.train_NASNetMobile(model, 2)
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_3 (InputLayer)            (None, 96, 96, 3)    0
# __________________________________________________________________________________________________
# NASNet (Model)                  (None, 3, 3, 1056)   4269716     input_3[0][0]
# __________________________________________________________________________________________________
# global_max_pooling2d_2 (GlobalM (None, 1056)         0           NASNet[1][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_2 (Glo (None, 1056)         0           NASNet[1][0]
# __________________________________________________________________________________________________
# flatten_2 (Flatten)             (None, 9504)         0           NASNet[1][0]
# ...

# %%
keras_models.show_final_history()
